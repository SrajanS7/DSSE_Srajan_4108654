# %%
def count_words(text):
    return len(text.split())

text = "Hello world"
result = count_words(text)

print("Text:", text)
print("Word Count:", result)
# Out:
# Text: Hello world
# Word Count: 2
